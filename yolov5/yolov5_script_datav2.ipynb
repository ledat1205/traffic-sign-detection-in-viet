# %% [markdown]
# ## 1. Import

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v6.1-243-g7cef03d Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 38.7/78.2 GB disk)

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 2. Train

# %% [markdown]
# test 3epoch rồi train 200epoch

# %%
# !python train.py --img 640 --batch 16 --epochs 200 --data /content/drive/MyDrive/CV_nangcao/train/yolov5/dataV2.yaml --weights yolov5m.pt --hyp /content/drive/MyDrive/CV_nangcao/train/yolov5/customHyp.yaml --project /content/drive/MyDrive/CV_nangcao/train/yolov5/yolov5_result_dataV2 --device 0
# Out:
# train: weights=yolov5m.pt, cfg=, data=/content/drive/MyDrive/CV_nangcao/train/yolov5/dataV2.yaml, hyp=/content/drive/MyDrive/CV_nangcao/train/yolov5/customHyp.yaml, epochs=200, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=0, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=/content/drive/MyDrive/CV_nangcao/train/yolov5/yolov5_result_dataV2, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.1-242-ga80dd66 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %%
# !python train.py --resume  /content/drive/MyDrive/CV_nangcao/train/yolov5/yolov5_result_dataV2/exp3/weights/last.pt
# Out:
# train: weights=yolov5s.pt, cfg=, data=data/coco128.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=300, batch_size=16, imgsz=640, rect=False, resume=/content/drive/MyDrive/CV_nangcao/train/yolov5/yolov5_result_dataV2/exp3/weights/last.pt, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# Resuming training from /content/drive/MyDrive/CV_nangcao/train/yolov5/yolov5_result_dataV2/exp3/weights/last.pt
# YOLOv5 🚀 v6.1-243-g7cef03d Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# ...
